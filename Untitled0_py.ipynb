# %% [markdown]
# <a href="https://colab.research.google.com/github/Eugene-boop/generator/blob/master/Untitled0_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python /content/NeuroGenerator.py --text=/content/feed.txt --epochs=10 --out_len=4000
# Out:
# Using TensorFlow backend.
# Vocab size: 98
# Word_tokens: False
# x.shape: (7968, 50)
# y.shape: (7968, 50, 1)
# Training...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10
# 7968/7968 [==============================] - 36s 4ms/step - loss: 3.1301 - accuracy: 0.1619
# Epoch 2/10
# 7968/7968 [==============================] - 34s 4ms/step - loss: 2.6072 - accuracy: 0.2518
# Epoch 3/10
# 7968/7968 [==============================] - 35s 4ms/step - loss: 2.4473 - accuracy: 0.2972
# Epoch 4/10
# 7968/7968 [==============================] - 35s 4ms/step - loss: 2.3309 - accuracy: 0.3274
# Epoch 5/10
# 7968/7968 [==============================] - 35s 4ms/step - loss: 2.2395 - accuracy: 0.3518
# Epoch 6/10
# ...
